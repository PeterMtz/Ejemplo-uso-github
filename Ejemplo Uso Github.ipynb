# %% [markdown]
# # 🤝 Colaboración con GitHub en Proyectos de Data Science

# %% [markdown]
# Este notebook sirve como guía introductoria para trabajar colaborativamente en un proyecto de ciencia de datos usando **Git** y **GitHub**.
#
# 💡 **Objetivos:**
# - Entender el propósito de Git y GitHub.
# - Aprender cómo colaborar usando ramas (branches), pull requests y commits.
# - Practicar una dinámica de colaboración simulando un proyecto de predicción.

# %% [markdown]
# ## 🧠 ¿Qué es GitHub?
#
# GitHub es una plataforma basada en la web que permite almacenar código, hacer seguimiento de cambios y colaborar en equipo mediante Git.
#
# ### ¿Para qué sirve en Data Science?
# - Compartir código y notebooks.
# - Documentar experimentos.
# - Versionar scripts de limpieza, entrenamiento y evaluación de modelos.
# - Revisar código con pull requests.
# - Construir portafolios públicos.

# %%
import pandas as pd

# Crear un DataFrame de ejemplo
df = pd.DataFrame({
    'fecha': pd.date_range(start='2024-01-01', periods=10, freq='D'),
    'ventas': [10, 13, 15, 18, 17, 20, 19, 22, 23, 25]
})

df.head()
# Out:
#        fecha  ventas
# 0 2024-01-01      10
# 1 2024-01-02      13
# 2 2024-01-03      15
# 3 2024-01-04      18
# 4 2024-01-05      17

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 6))
plt.plot(df['fecha'], df['ventas'], marker='o')
plt.title('Ejemplo de Serie de Tiempo: Ventas Diarias')
plt.xlabel('Fecha')
plt.ylabel('Ventas')
plt.grid(True)
plt.show()

# %%
# Esta es mi parte -Pedro Martinez-

import pandas as pd

# Crear un DataFrame de ejemplo
df = pd.DataFrame({
    'fecha': pd.date_range(start='2024-01-01', periods=10, freq='D'),
    'ventas': [23, 33, 43, 18, 53, 20, 63, 73, 83, 20]
})

df.head()
# Out:
#        fecha  ventas
# 0 2024-01-01      23
# 1 2024-01-02      33
# 2 2024-01-03      43
# 3 2024-01-04      18
# 4 2024-01-05      53

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 6))
plt.plot(df['fecha'], df['ventas'], marker='o')
plt.title('Ejemplo de Serie de Tiempo: Ventas Diarias')
plt.xlabel('Fecha')
plt.ylabel('Ventas')
plt.grid(True)
plt.show()
